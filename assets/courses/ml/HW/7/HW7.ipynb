# %% [markdown]
# Տնային առաջադրանքը կատարելու վերջնաժամկետը **05.07.2021 15:30** է։ Առաջադրանքները կատարելուց հետո, պետք է
#
# 1. ներբեռնեք այս ֆայլը ձեր համակարգիչ (`File` $\to$ `Download .ipynb`)
#
# 2. ներբեռնեք լրացված ``.py`` ֆայլերը
#
# 3. վերոնշյալ ֆայլերը ``.zip`` արեք և վերնագրեք հետևյալ ֆորմատով՝
#     *HW7_AnunAzganun.zip*
#
# 4. ուղարկեք ֆայլը **fast.1991.ml@gmail.com** հասցեին` նամակի թեմա (subject) դաշտում գրելով **ML7**
#
# **Ուշադրություն**․
# Վերոնշյալ պայմաններին չբավարարելու դեպքում ձեր աշխատանքը չի գնահատվի։

# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid') # Plot style

from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.model_selection import train_test_split

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Complete the `Adaboost` class in `Lab_files/Lab7/boosting.py` script and use the small digits dataset from sklearn to test it.
# Here is the [description](https://archive.ics.uci.edu/ml/datasets/Optical+Recognition+of+Handwritten+Digits) of the data that we will use to test our models.

# %%
from boosting import *
from sklearn import datasets
data = datasets.load_digits(n_class=2) # taking only 0 and 1 digits

# %%
X = data.data
y = data.target
y[y == 0] = -1 # changing the encoding for Adaboost

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.5,
                                                    random_state=0)

# %%
model = Adaboost(30)
model.fit(X_train, y_train)
print('Train accuracy: ', accuracy_score(model.predict(X_train), y_train))
print('Test accuracy: ', accuracy_score(model.predict(X_test), y_test))
# Out:
# Model Training: 100% [------------------------------------------] Time: 0:00:07
# Train accuracy:  1.0
# Test accuracy:  1.0

# %% [markdown]
# You should get close to 100% accuracy on both sets.

# %% [markdown]
# # Gradient Boosting Regressor

# %% [markdown]
# Complete the `GradientBoostingRegressor` class in `Lab_files/Lab7/boosting.py` script and use `Lab_files/Lab6/data.csv` file to test the implementation. You can use yor implementation for `RegressionTree`, but if you don't have it, then you can use sklearn's version.

# %%
data = pd.read_csv("data.csv", index_col = 0)

X_train, X_test, y_train, y_test = train_test_split(data.drop(columns=['y']),
                                                    data['y'], test_size=0.5,
                                                    random_state=0)

# %%
model = GradientBoostingRegressor(n_estimators=100)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(mean_squared_error(y_pred, y_test))
# Out:
# Model Training: 100% [------------------------------------------] Time: 0:04:15
# 101.3689470459634

# %% [markdown]
# You should get about $100$ MSE (±10) when trying your implementation.

# %% [markdown]
# # Gradient Boosting Classifier

# %% [markdown]
# Now complete the `GradientBoostingClassifier` class in `Lab_files/Lab7/boosting.py` script and use the small digits dataset from sklearn to test it.

# %%
data = datasets.load_digits() # taking all digits

# %%
X = data.data
y = data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.5,
                                                    random_state=0)

# %%
y_train_onehot = np.array(pd.get_dummies(y_train))

# %%
model = GradientBoostingClassifier(learning_rate=0.1)
model.fit(X_train, y_train_onehot)
print('Train accuracy: ', accuracy_score(model.predict(X_train), y_train))
print('Test accuracy: ', accuracy_score(model.predict(X_test), y_test))
# Out:
# Model Training: 100% [------------------------------------------] Time: 0:00:01
# Train accuracy:  1.0
# Test accuracy:  0.9577308120133482
